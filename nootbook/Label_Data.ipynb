# %%
# !pip install pandas
# !pip install  numpy
# !pip install nltk

# %%
#untuk komputasi numerik
import numpy as np

#memproses pengolahan teks
import nltk

#membantu mempermudah manipulasi data teks
import string

#hilangkan notif karena migrasi dari python
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #New Section

# %%
#import Library yang dubutuhkan
import pandas as pd
from tqdm import tqdm,notebook
import warnings
warnings.filterwarnings('ignore')

pd.pandas.set_option('display.max_columns',None)
pd.pandas.set_option('display.max_rows',None)
pd.pandas.set_option('display.max_colwidth',None)
pd.pandas.set_option('display.width',None)

# %%
df = pd.read_csv('/content/DataSetWhatsApp.csv')
df.head()
# Out:
#           userName  score                   at  \
# 0  Pengguna Google      4  2026-06-01 04:14:48
# 1  Pengguna Google      3  2026-06-01 04:14:08
# 2  Pengguna Google      5  2026-06-01 04:13:29
# 3  Pengguna Google      1  2026-06-01 04:10:20
# 4  Pengguna Google      3  2026-06-01 04:09:07
#
#                                                                                                                                                                                                                                                                                                                                                                                                  content
# ...

# %%
df['sentimen'] = df['score'].map({1.0:0,2.0:0,3.0:1, 4.0:1, 5.0:1})

# %%
#ambil teks aja untuk kita labelkan
dataku = pd.DataFrame(df[['content','sentimen']])
dataku.head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                  content  \
# 0                                                                                                                                                                                                                                                                                                                 WhatsAppnya bagus updet dong tapi aku suka bisa dibuat telefon wa dan juga lain lainya
# ...

# %%
my_df = dataku[['content','sentimen']]

# %%
#simpan dataset ke dalam file
my_df.to_csv("DataSetWhatsApp.csv",index = False)
